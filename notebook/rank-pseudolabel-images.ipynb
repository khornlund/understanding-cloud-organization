# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import h5py
import cv2
from scipy.stats import rankdata
from tqdm import tqdm
from pathlib import Path
from uco.data_loader import pivot_df

# %%
pseudo_dir = Path('../data/pseudo')

# %%
def get_df():
    df = pd.read_csv('../data/raw/gibs.csv')
    df = pivot_df(df).reset_index()[['Image']]
    return df

# %%
with h5py.File(pseudo_dir / 'avg-seg-predictions.h5', 'r') as f:
    for k in f.keys():
        print(k)
# Out:
# deeplabv3_resnet101-DeepLabV3
# efficientnet-b0-FPN
# efficientnet-b0-Unet
# efficientnet-b2-FPN
# efficientnet-b2-Unet
# efficientnet-b5-FPN
# efficientnet-b5-Unet
# efficientnet-b6-FPN
# inceptionresnetv2-Unet
# resnext101_32x8d-FPN
# resnext101_32x8d-Unet

# %%
# Save prediction ranks based on segmentation models
with h5py.File(pseudo_dir / 'avg-seg-predictions.h5', 'r') as f:
    group_names = [k for k in f.keys() if k != 'average']
    for c in tqdm(list(range(4))):
        df = get_df()
        for k in group_names:
            preds = f[k][:, c, :, :]
            totals = np.sum(preds, axis=1)
            totals = np.sum(totals, axis=1)
            ranks = rankdata(totals)
            df[k] = ranks
        df.set_index('Image', inplace=True)
        df['mean'] = df.apply(lambda row: row.mean(), axis=1)
        df['rank'] = rankdata(df['mean'])
        df.to_csv(pseudo_dir / f'pseudo-segmentation-ranks-c{c}.csv')
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
#  25%|██▌       | 1/4 [00:58<02:55, 58.47s/it]
#  50%|█████     | 2/4 [01:51<01:53, 56.79s/it]
#  75%|███████▌  | 3/4 [02:44<00:55, 55.79s/it]
# 100%|██████████| 4/4 [03:37<00:00, 54.48s/it]

# %%
with h5py.File(pseudo_dir / 'avg-clas-predictions.h5', 'r') as f:
    for k in f.keys():
        print(k)
# Out:
# average
# efficientnet-b0-EfficientNet
# efficientnet-b2-EfficientNet
# efficientnet-b4-EfficientNet
# resnext50d_32x4d-TIMM
# tv_resnext50_32x4d-TIMM

# %%
# Save prediction ranks based on classification models
with h5py.File(pseudo_dir / 'avg-clas-predictions.h5', 'r') as f:
    k = 'average'
    for c in range(4):
        df = get_df()
        preds = f[k][:, c]
        ranks = rankdata(preds)
        df['rank'] = ranks
        df.to_csv(pseudo_dir / f'pseudo-classification-ranks-c{c}.csv', index=False)

# %%
df = get_df()
n_total = df.shape[0]
n_selected = 1500
cutoff = n_total - n_selected

for c in range(4):
    df_seg  = pd.read_csv(pseudo_dir / f'pseudo-segmentation-ranks-c{c}.csv')
    df_clas = pd.read_csv(pseudo_dir / f'pseudo-classification-ranks-c{c}.csv')
    
    df_seg['selected']  = df_seg['rank'] > cutoff
    df_clas['selected'] = df_clas['rank'] > cutoff
    df[str(c)] = np.logical_and(df_seg['selected'], df_clas['selected'])
df.to_csv(pseudo_dir / 'selected.csv', index=False)

# %%
for c in range(4):
    print(df[str(c)].sum())
df.head(60)
# Out:
# 1339
# 1376
# 1329
# 1308
#                                                 Image      0      1      2  \
# 0   2002-01-01-domain-a-MODIS-Terra-CorrectedRefle...   True  False  False
# 1   2002-01-01-domain-b-MODIS-Terra-CorrectedRefle...   True  False  False
# 2   2002-01-01-domain-c-MODIS-Terra-CorrectedRefle...  False   True   True
# 3   2002-01-02-domain-a-MODIS-Terra-CorrectedRefle...   True  False  False
# 4   2002-01-02-domain-b-MODIS-Terra-CorrectedRefle...   True  False   True
# 5   2002-01-02-domain-c-MODIS-Terra-CorrectedRefle...  False   True  False
# 6   2002-01-03-domain-a-MODIS-Terra-CorrectedRefle...   True   True  False
# 7   2002-01-03-domain-b-MODIS-Terra-CorrectedRefle...  False  False  False
# 8   2002-01-03-domain-c-MODIS-Terra-CorrectedRefle...  False   True  False
# 9   2002-01-04-domain-a-MODIS-Terra-CorrectedRefle...   True   True  False
# 10  2002-01-04-domain-b-MODIS-Terra-CorrectedRefle...   True  False  False
# 11  2002-01-04-domain-c-MODIS-Terra-CorrectedRefle...  False  False  False
# 12  2002-01-05-domain-a-MODIS-Terra-CorrectedRefle...   True   True  False
# 13  2002-01-05-domain-b-MODIS-Terra-CorrectedRefle...  False  False  False
# 14  2002-01-05-domain-c-MODIS-Terra-CorrectedRefle...  False  False  False
# 15  2002-01-06-domain-a-MODIS-Terra-CorrectedRefle...   True  False   True
# 16  2002-01-06-domain-b-MODIS-Terra-CorrectedRefle...   True  False  False
# 17  2002-01-06-domain-c-MODIS-Terra-CorrectedRefle...  False  False  False
# 18  2002-01-07-domain-a-MODIS-Terra-CorrectedRefle...   True  False   True
# 19  2002-01-07-domain-b-MODIS-Terra-CorrectedRefle...   True  False  False
# 20  2002-01-07-domain-c-MODIS-Terra-CorrectedRefle...  False   True  False
# 21  2002-01-08-domain-a-MODIS-Terra-CorrectedRefle...   True  False   True
# 22  2002-01-08-domain-b-MODIS-Terra-CorrectedRefle...  False  False   True
# 23  2002-01-08-domain-c-MODIS-Terra-CorrectedRefle...  False   True  False
# 24  2002-01-09-domain-a-MODIS-Terra-CorrectedRefle...   True   True  False
# 25  2002-01-09-domain-b-MODIS-Terra-CorrectedRefle...   True  False  False
# 26  2002-01-09-domain-c-MODIS-Terra-CorrectedRefle...  False   True  False
# 27  2002-01-10-domain-a-MODIS-Terra-CorrectedRefle...  False   True  False
# 28  2002-01-10-domain-b-MODIS-Terra-CorrectedRefle...   True  False  False
# 29  2002-01-10-domain-c-MODIS-Terra-CorrectedRefle...   True   True  False
# 30  2002-01-11-domain-a-MODIS-Terra-CorrectedRefle...   True   True  False
# 31  2002-01-11-domain-b-MODIS-Terra-CorrectedRefle...  False  False  False
# 32  2002-01-11-domain-c-MODIS-Terra-CorrectedRefle...  False   True  False
# 33  2002-01-12-domain-a-MODIS-Terra-CorrectedRefle...  False   True  False
# 34  2002-01-12-domain-b-MODIS-Terra-CorrectedRefle...  False   True   True
# 35  2002-01-12-domain-c-MODIS-Terra-CorrectedRefle...  False   True  False
# 36  2002-01-13-domain-a-MODIS-Terra-CorrectedRefle...   True  False   True
# 37  2002-01-13-domain-b-MODIS-Terra-CorrectedRefle...   True  False  False
# 38  2002-01-13-domain-c-MODIS-Terra-CorrectedRefle...  False   True  False
# 39  2002-01-14-domain-a-MODIS-Terra-CorrectedRefle...   True  False   True
# 40  2002-01-14-domain-b-MODIS-Terra-CorrectedRefle...   True  False  False
# 41  2002-01-14-domain-c-MODIS-Terra-CorrectedRefle...  False  False   True
# 42  2002-01-15-domain-a-MODIS-Terra-CorrectedRefle...   True  False   True
# 43  2002-01-15-domain-b-MODIS-Terra-CorrectedRefle...   True  False  False
# 44  2002-01-15-domain-c-MODIS-Terra-CorrectedRefle...   True  False  False
# 45  2002-01-16-domain-a-MODIS-Terra-CorrectedRefle...  False  False   True
# 46  2002-01-16-domain-b-MODIS-Terra-CorrectedRefle...   True  False  False
# 47  2002-01-16-domain-c-MODIS-Terra-CorrectedRefle...  False   True  False
# 48  2002-01-17-domain-a-MODIS-Terra-CorrectedRefle...  False  False   True
# 49  2002-01-17-domain-b-MODIS-Terra-CorrectedRefle...   True  False  False
# 50  2002-01-17-domain-c-MODIS-Terra-CorrectedRefle...  False   True  False
# 51  2002-01-18-domain-a-MODIS-Terra-CorrectedRefle...  False  False   True
# 52  2002-01-18-domain-b-MODIS-Terra-CorrectedRefle...   True  False  False
# 53  2002-01-18-domain-c-MODIS-Terra-CorrectedRefle...  False   True  False
# 54  2002-01-19-domain-a-MODIS-Terra-CorrectedRefle...  False  False   True
# 55  2002-01-19-domain-b-MODIS-Terra-CorrectedRefle...  False  False  False
# 56  2002-01-19-domain-c-MODIS-Terra-CorrectedRefle...  False   True  False
# 57  2002-01-20-domain-a-MODIS-Terra-CorrectedRefle...  False  False   True
# 58  2002-01-20-domain-b-MODIS-Terra-CorrectedRefle...  False  False   True
# 59  2002-01-20-domain-c-MODIS-Terra-CorrectedRefle...  False   True  False
#
#         3
# 0   False
# 1   False
# 2    True
# 3   False
# 4   False
# 5   False
# 6   False
# 7   False
# 8   False
# 9   False
# 10  False
# 11   True
# 12  False
# 13  False
# 14   True
# 15  False
# 16  False
# 17   True
# 18  False
# 19  False
# 20  False
# 21  False
# 22   True
# 23  False
# 24  False
# 25  False
# 26  False
# 27  False
# 28  False
# 29  False
# 30  False
# 31  False
# 32   True
# 33  False
# 34  False
# 35  False
# 36  False
# 37  False
# 38   True
# 39  False
# 40  False
# 41   True
# 42  False
# 43  False
# 44  False
# 45  False
# 46   True
# 47  False
# 48  False
# 49   True
# 50  False
# 51   True
# 52  False
# 53  False
# 54  False
# 55   True
# 56  False
# 57   True
# 58   True
# 59   True
