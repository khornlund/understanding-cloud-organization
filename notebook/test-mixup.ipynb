# %%
from pathlib import Path
import pandas as pd
import numpy as np
import albumentations as A
import matplotlib.pyplot as plt
import cv2
from uco.data_loader import RLE, pivot_df

# %%
train_csv = '../data/raw/train.csv'
df = pd.read_csv(train_csv)
df = pivot_df(df)
df.head()
# Out:
#                                                           rle0  \
# Image
# 0011165.jpg  264918 937 266318 937 267718 937 269118 937 27...
# 002be4f.jpg  233813 878 235213 878 236613 878 238010 881 23...
# 0031ae9.jpg  3510 690 4910 690 6310 690 7710 690 9110 690 1...
# 0035239.jpg                                                NaN
# 003994e.jpg  2367966 18 2367985 2 2367993 8 2368002 62 2369...
#
#                                                           rle1  \
# Image
# 0011165.jpg  1355565 1002 1356965 1002 1358365 1002 1359765...
# 002be4f.jpg  1339279 519 1340679 519 1342079 519 1343479 51...
# 0031ae9.jpg  2047 703 3447 703 4847 703 6247 703 7647 703 9...
# 0035239.jpg  100812 462 102212 462 103612 462 105012 462 10...
# 003994e.jpg                                                NaN
#
#                                                           rle2  \
# Image
# 0011165.jpg                                                NaN
# ...

# %%
img_dir = Path('../data/raw/train_images')
img_filenames = list(img_dir.glob('*.jpg'))
len(img_filenames)
# Out:
# 5546

# %%
imgs = [cv2.imread(str(f)) for f in img_filenames[10:13]]
rles = [df.loc[f.name, ['rle0', 'rle1', 'rle2', 'rle3']] for f in img_filenames[10:13]]
masks = [np.stack([RLE.from_str(s).to_mask() for s in row], axis=2) for row in rles]

# %%
def plot_imgs(imgs, masks):
    fig, axs = plt.subplots(6, 1, figsize=(16, 16))
    for i in range(3):
        axs[i*2].imshow(imgs[i])
        axs[i*2+1].imshow(masks[i].sum(axis=2))
    plt.show()
plot_imgs(imgs, masks)

# %%
plt.imshow(imgs[0])

# %%
imgs[0].dtype
# Out:
# dtype('uint8')

# %%
nonzero = (imgs[0] < 8).all(axis=2)
nonzero.shape
# Out:
# (1400, 2100)

# %%
img = imgs[1].copy()
#mask = np.where(img<8, img, 0)
mask = (img < 4).all(axis=2)
img[mask] = 255
plt.imshow(img)
