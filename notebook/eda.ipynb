# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
from torchvision import transforms as T
from albumentations.pytorch import ToTensorV2
import albumentations as A

from uco.data_loader import CloudDatasetTrainVal

# %%
DATA_DIR = Path('../data/raw')
TRAIN_DIR = DATA_DIR / 'train_images'
train_filenames = list(TRAIN_DIR.glob('*.jpg'))
print(len(train_filenames))
# Out:
# 5546

# %%
def read_rgb(f):
    img = cv2.imread(f)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    return img

def read(f):
    img = cv2.imread(f)

# %%
random_filename = str(np.random.choice(train_filenames))
img = read_rgb(random_filename)

# %%
plt.imshow(img)

# %%
train_csv = DATA_DIR / 'train.csv'
df = pd.read_csv(train_csv)
df.head()
# Out:
#           Image_Label                                      EncodedPixels
# 0    0011165.jpg_Fish  264918 937 266318 937 267718 937 269118 937 27...
# 1  0011165.jpg_Flower  1355565 1002 1356965 1002 1358365 1002 1359765...
# 2  0011165.jpg_Gravel                                                NaN
# 3   0011165.jpg_Sugar                                                NaN
# 4    002be4f.jpg_Fish  233813 878 235213 878 236613 878 238010 881 23...

# %%
df['Image'], df['Label'] = zip(*df['Image_Label'].str.split('_'))
df = df.pivot(index='Image', columns='Label', values='EncodedPixels')
df.columns = [f'rle{c}' for c in range(4)]
df['n_classes'] = df.count(axis=1)
df.head()
# Out:
#                                                           rle0  \
# Image
# 0011165.jpg  264918 937 266318 937 267718 937 269118 937 27...
# 002be4f.jpg  233813 878 235213 878 236613 878 238010 881 23...
# 0031ae9.jpg  3510 690 4910 690 6310 690 7710 690 9110 690 1...
# 0035239.jpg                                                NaN
# 003994e.jpg  2367966 18 2367985 2 2367993 8 2368002 62 2369...
#
#                                                           rle1  \
# Image
# 0011165.jpg  1355565 1002 1356965 1002 1358365 1002 1359765...
# 002be4f.jpg  1339279 519 1340679 519 1342079 519 1343479 51...
# 0031ae9.jpg  2047 703 3447 703 4847 703 6247 703 7647 703 9...
# 0035239.jpg  100812 462 102212 462 103612 462 105012 462 10...
# 003994e.jpg                                                NaN
#
#                                                           rle2  \
# Image
# 0011165.jpg                                                NaN
# ...

# %%
tsfm = A.Compose([
    
    # ToTensorV2()
])

def to_numpy(img):
    img = T.ToPILImage()(img)
    return np.array(img)

# %%
ds = CloudDatasetTrainVal(df, DATA_DIR, tsfm, True)

# %%
random_idx = np.random.choice(np.arange(df.shape[0]))
img, mask = ds[random_idx]
# img, mask = to_pil(img), to_pil(mask)

fig, ax = plt.subplots(5, 1, figsize=(12, 24))
ax[0].imshow(img)
ax[1].imshow(mask[:, :, 0])
ax[2].imshow(mask[:, :, 1])
ax[3].imshow(mask[:, :, 2])
ax[4].imshow(mask[:, :, 3])
plt.show()

# %%
# ?mask
